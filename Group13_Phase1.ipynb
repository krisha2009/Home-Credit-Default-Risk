# %% [markdown]
# ----------
#
# <h1>
# Home Credit Default Rate
# </h1>
# <h4>
# Group 13: Kalyani Malokar, Krisha Mehta, Kunal Mehra, William Cutchin
# </h4>
# <h4>
# Indiana University Bloomington, Luddy School of Informatics, Computing, and Engineering
# </h4>
# <h4>
# INFO-I-526: Applications of Machine Learning
# </h4>
# <h4>
# Dr. James Shanahan
# </h4>
# <h4>
# April 4, 2023
# </h4>
#
# ----------

# %% [markdown]
# # The Team
# ## Group 13
# | Group Member      | Member Picture |
# | ----------- | ----------- |
# | Kalyani Malokar (kmalokar@iu.edu)      | <img src="images/kalyanimalokar_teamshot.jpg" width = 150px />  |
# | Krisha Mehta (krimeht@iu.edu)   | <img src="images/krishamehta_teamshot.jpg" width = 150px />    |
# |Kunal Mehra (kumehra@iu.edu) |     <img src="images/kunalmehra_teamshot.png" width = 150px />     |
# | William Cutchin (wcutchin@iu.edu) |   <img src="images/williamcutchin_teamshot.jpg" width = 150px /> |

# %% [markdown]
# ----------
# # Phase Leader Plan
# <table>
#   <tr>
#    <td>Phase Number
#    </td>
#    <td>Team Member
#    </td>
#    <td>Phase Objective Delegation
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 1:</span>
# <p>
# Project Proposal
#    </td>
#    <td>William Cutchin (Phase Leader)
#    </td>
#    <td>
# <ul>
#
# <li>Schedule Meetings, Organize Tasks, Lead Group Meetings
#
# <li>Format Project Proposal
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 1:</span>
# <p>
# Project Proposal
#    </td>
#    <td>Krisha Mehta
#    </td>
#    <td>
# <ul>
#
# <li>Data Description
#
# <li>Machine Algorithms and Metrics
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 1:</span>
# <p>
# Project Proposal
#    </td>
#    <td>Kalyani Malokar
#    </td>
#    <td>
# <ul>
#
# <li>Machine Learning Pipeline (Diagram)
#
# <li>Gantt Chart of Tasks
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 1:</span>
# <p>
# Project Proposal
#    </td>
#    <td>Kunal Mehra
#    </td>
#    <td>
# <ul>
#
# <li>Machine Learning Pipeline Steps & Descriptions
#
# <li>Additional Algorithms (Loss Functions)
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 2:</span>
# <p>
# EDA & Basic Pipelines
#    </td>
#    <td>Krisha Mehta
# <p>
# (Phase Leader)
#    </td>
#    <td>
# <ul>
#
# <li>Schedule Meetings, Organize Tasks, Lead Group Meetings
#
# <li>Data Retrieval
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 2:</span>
# <p>
# EDA & Basic Pipelines
#    </td>
#    <td>Kalyani Malokar
#    </td>
#    <td>
# <ul>
#
# <li>Feature Engineering (Round 1)
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 2:</span>
# <p>
# EDA & Basic Pipelines
#    </td>
#    <td>Kunal Mehra
#    </td>
#    <td>
# <ul>
#
# <li>Hyper Parameter Tuning (Round 1)
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 2:</span>
# <p>
# EDA & Basic Pipelines
#    </td>
#    <td>William Cutchin
#    </td>
#    <td>
# <ul>
#
# <li>Exploratory Data Analysis
#
# <li>Video Presentation
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 3:</span>
# <p>
# Feature Engineering & Hyperparameter Tuning
#    </td>
#    <td>Kalyani Malokar (Phase Leader)
#    </td>
#    <td>
# <ul>
#
# <li>Schedule Meetings, Organize Tasks, Lead Group Meetings
#
# <li>Feature Selection
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 3:</span>
# <p>
# Feature Engineering & Hyperparameter Tuning
#    </td>
#    <td>Kunal Mehra
#    </td>
#    <td>
# <ul>
#
# <li>Hyper Parameter Tuning (Round 2)
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 3:</span>
# <p>
# Feature Engineering & Hyperparameter Tuning
#    </td>
#    <td>William Cutchin
#    </td>
#    <td>
# <ul>
#
# <li>Feature Engineering (Round 2)
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 3:</span>
# <p>
# Feature Engineering & Hyperparameter Tuning
#    </td>
#    <td>Krisha Mehta
#    </td>
#    <td>
# <ul>
#
# <li>Video Presentation
#
# <li>Ensemble Methods
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 4:</span>
# <p>
# Final Submission
#    </td>
#    <td>Kunal Mehra
# <p>
# (Phase Leader)
#    </td>
#    <td>
# <ul>
#
# <li>Neural Network Implementation
#
# <li>Schedule Meetings, Organize Tasks, Lead Group Meetings
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 4:</span>
# <p>
# Final Submission
#    </td>
#    <td>William Cutchin
#    </td>
#    <td>
# <ul>
#
# <li>Final Report
#
# <li>Video Presentation
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 4:</span>
# <p>
# Final Submission
#    </td>
#    <td>Krisha Mehta
#    </td>
#    <td>
# <ul>
#
# <li>Advanced Model Architectures
# </li>
# </ul>
#    </td>
#   </tr>
#   <tr>
#    <td><span style="text-decoration:underline;">Phase 4:</span>
# <p>
# Final Submission
#    </td>
#    <td>Kalyani Malokar
#    </td>
#    <td>
# <ul>
#
# <li>Advanced Loss & Additional Functions
# </li>
# </ul>
#    </td>
#   </tr>
# </table>

# %% [markdown]
# ----------
# # Credit Assignment Plan

# %% [markdown]
# ## Phase 1
# <table>
#   <tr>
#    <td>Task
#    </td>
#    <td>Task Description
#    </td>
#    <td>Assigned Member
#    </td>
#    <td>Estimated Hours
#    </td>
#    <td>Actual Hours
#    </td>
#    <td>Start Date
#    </td>
#    <td>Completion Date
#    </td>
#   </tr>
#   <tr>
#    <td>Format Project Proposal
#    </td>
#    <td>Communicate to find group members’ desired tasks, write the abstract, and collect and display
# <p>
# Team Photos.
#    </td>
#    <td>William Cutchin
#    </td>
#    <td>5
#    </td>
#    <td>5.5
#    </td>
#    <td>28/3/2023
#    </td>
#    <td>4/4/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Data Description
#    </td>
#    <td>Create table figures of data sources with descriptions
#    </td>
#    <td>Krisha Mehta
#    </td>
#    <td>1
#    </td>
#    <td>1
#    </td>
#    <td>29/3/2023
#    </td>
#    <td>4/4/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Machine Algorithms and Metrics
#    </td>
#    <td>Research and select appropriate  metrics and algorithms for the datasets.
#    </td>
#    <td>Krisha Mehta
#    </td>
#    <td>1.5
#    </td>
#    <td>2
#    </td>
#    <td>04/03/2023
#    </td>
#    <td>04/04/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Machine Learning Pipeline (Diagram)
#    </td>
#    <td>Construct a block diagram which visualizes the suggested pipeline steps.
#    </td>
#    <td>Kalyani Malokar
#    </td>
#    <td>1.5
#    </td>
#    <td>2
#    </td>
#    <td>03/31/2023
#    </td>
#    <td>04/03/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Gantt Chart of Tasks
#    </td>
#    <td>Construct a Gantt chart which displays the waterfall of tasks and their dependencies.
#    </td>
#    <td>Kalyani Malokar
#    </td>
#    <td>1
#    </td>
#    <td>1
#    </td>
#    <td>04/04/2023
#    </td>
#    <td>04/04/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Machine Learning Pipeline Steps & Descriptions
#    </td>
#    <td>Describe and reason through the steps the pipeline will take.
#    </td>
#    <td>Kunal Mehra
#    </td>
#    <td>2
#    </td>
#    <td>2
#    </td>
#    <td>03/28/2023
#    </td>
#    <td>03/30/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Additional Algorithms (Loss Functions)
#    </td>
#    <td>Select reasonable loss functions, describe them, and display their formula
#    </td>
#    <td>Kunal Mehra
#    </td>
#    <td>0.5
#    </td>
#    <td>0.5
#    </td>
#    <td>03/31/2023
#    </td>
#    <td>04/04/2023
#    </td>
#   </tr>
# </table>

# %% [markdown]
# ## Phase 2
# <table>
#   <tr>
#    <td>Task
#    </td>
#    <td>Task Description
#    </td>
#    <td>Assigned Member
#    </td>
#    <td>Estimated Hours
#    </td>
#    <td>Actual Hours
#    </td>
#    <td>Start Date
#    </td>
#    <td>Completion Date
#    </td>
#   </tr>
#   <tr>
#    <td>Data Retrieval
#    </td>
#    <td>Retrieve data from the Kaggle API and begin loading the data and pre-processing.
#    </td>
#    <td>Krisha Mehta
#    </td>
#    <td>3
#    </td>
#    <td>TBD
#    </td>
#    <td>04/04/2023
#    </td>
#    <td>04/05/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Feature Engineering (Round 1)
#    </td>
#    <td>Develop and deploy initial feature engineering, applying statistical techniques and
# <p>
# log experiments.
#    </td>
#    <td>Kalyani Malokar
#    </td>
#    <td>6
#    </td>
#    <td>TBD
#    </td>
#    <td>04/05/2023
#    </td>
#    <td>04/06/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Hyper Parameter Tuning
# <p>
# (Round 1)
#    </td>
#    <td>Test ranges of parameters for the given features, record experiment results and optimize.
#    </td>
#    <td>Kunal Mehra
#    </td>
#    <td>6
#    </td>
#    <td>TBD
#    </td>
#    <td>04/05/2023
#    </td>
#    <td>04/07/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Exploratory Data Analysis
#    </td>
#    <td>Handle missing values, perform descriptive analysis, and identify correlations.
#    </td>
#    <td>William Cutchin
#    </td>
#    <td>4.5
#    </td>
#    <td>TBD
#    </td>
#    <td>04/07/2023
#    </td>
#    <td>04/11/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Video Presentation
#    </td>
#    <td>Summarize the project, describe work completed, layout plans for the future, and discuss blockers.
#    </td>
#    <td>William Cutchin
#    </td>
#    <td>2
#    </td>
#    <td>TBD
#    </td>
#    <td>04/10/2023
#    </td>
#    <td>04/11/2023
#    </td>
#   </tr>
# </table>

# %% [markdown]
# ## Phase 3
# <table>
#   <tr>
#    <td>Task
#    </td>
#    <td>Task Description
#    </td>
#    <td>Assigned Member
#    </td>
#    <td>Estimated Hours
#    </td>
#    <td>Actual Hours
#    </td>
#    <td>Start Date
#    </td>
#    <td>Completion Date
#    </td>
#   </tr>
#   <tr>
#    <td>Feature Selection
#    </td>
#    <td>Observe and compare results from Feature engineering and decide which features are worth exploring further.
#    </td>
#    <td>Kalyani Malokar
#    </td>
#    <td>7
#    </td>
#    <td>TBD
#    </td>
#    <td>04/11/2023
#    </td>
#    <td>04/12/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Hyper Parameter Tuning
# <p>
# (Round 2)
#    </td>
#    <td>Test ranges of parameters for the given features that have been selected by the feature selection step.
#    </td>
#    <td>Kunal Mehra
#    </td>
#    <td>6
#    </td>
#    <td>TBD
#    </td>
#    <td>04/13/2023
#    </td>
#    <td>04/14/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Feature Engineering (Round 2)
#    </td>
#    <td>Develop and deploy feature engineering on new selected features, log experiments and explore adding or removing features. Log these experiments.
#    </td>
#    <td>William Cutchin
#    </td>
#    <td>5
#    </td>
#    <td>TBD
#    </td>
#    <td>04/14/2023
#    </td>
#    <td>04/17/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Ensemble Methods
#    </td>
#    <td>Combine the multiple models or pipelines used into a single process. Log the results and compare.
#    </td>
#    <td>Krisha Mehta
#    </td>
#    <td>3.5
#    </td>
#    <td>TBD
#    </td>
#    <td>04/14/2023
#    </td>
#    <td>04/18/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Video Presentation
#    </td>
#    <td>Summarize the project, describe work completed, layout plans for the future, and discuss blockers.
#    </td>
#    <td>Krisha Mehta
#    </td>
#    <td>2
#    </td>
#    <td>TBD
#    </td>
#    <td>04/14/2023
#    </td>
#    <td>04/18/2023
#    </td>
#   </tr>
# </table>

# %% [markdown]
# ## Phase 4
# <table>
#   <tr>
#    <td>Task
#    </td>
#    <td>Task Description
#    </td>
#    <td>Assigned Member
#    </td>
#    <td>Estimated Hours
#    </td>
#    <td>Actual Hours
#    </td>
#    <td>Start Date
#    </td>
#    <td>Completion Date
#    </td>
#   </tr>
#   <tr>
#    <td>Neural Network Implementation
#    </td>
#    <td>Develop and deploy an effective neural network, given the reasonings of previous ML algorithms. Test and log all experiments.
#    </td>
#    <td>Kunal Mehra
#    </td>
#    <td>8
#    </td>
#    <td>TBD
#    </td>
#    <td>04/18/2023
#    </td>
#    <td>04/20/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Advanced Model Architectures
#    </td>
#    <td>Combine and understand previous models to construct an effective and advanced model.
#    </td>
#    <td>Krisha Mehta
#    </td>
#    <td>4.5
#    </td>
#    <td>TBD
#    </td>
#    <td>04/21/2023
#    </td>
#    <td>04/25/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Advanced Loss & Additional Functions
#    </td>
#    <td>Continue to iterate and experiment with loss functions, optimizing further the model’s performance.
#    </td>
#    <td>Kalyani Malokar
#    </td>
#    <td>4
#    </td>
#    <td>TBD
#    </td>
#    <td>04/21/2023
#    </td>
#    <td>04/25/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Final Report Formatting
#    </td>
#    <td>Accumulate all information and insight to be formatted into an attractive and logical report.
#    </td>
#    <td>William Cutchin
#    </td>
#    <td>8
#    </td>
#    <td>TBD
#    </td>
#    <td>04/18/2023
#    </td>
#    <td>04/25/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Video Presentation
#    </td>
#    <td>Summarize the project, describe work completed, report our successes and process, and describe how we could build on our submission.
#    </td>
#    <td>William Cutchin
#    </td>
#    <td>3
#    </td>
#    <td>TBD
#    </td>
#    <td>04/21/2023
#    </td>
#    <td>04/25/2023
#    </td>
#   </tr>
#   <tr>
#    <td>Final Report
#    </td>
#    <td>Compile and discuss all progress, development, visualizations, and findings to present to peers with great efficiency.
#    </td>
#    <td>All Members
#    </td>
#    <td>25
#    </td>
#    <td>TBD
#    </td>
#    <td>04/24/2023
#    </td>
#    <td>04/25/2023
#    </td>
#   </tr>
# </table>

# %% [markdown]
# ----------
# # Project Abstract
# <p>
# Home Credit Group is in pursuit of solutions to service individuals with little to no credit history in the loan industry. Home Credit Group looks to use alternative data that will help them decide if they are able to lend to these individuals. With the utilization of machine learning models, Home Credit Group hopes to be able to serve unbanked people with confidence. Our team aims to successfully aid in this process by utilizing our knowledge of machine learning pipelines, machine learning models, and data analysis. Specifically, we intend to deploy, train, and optimize linear regression models, random forest models, and a neural network using adagrad. We will measure our success, first, by the metric Home Credit Group uses Area Under Curve. We will also use accuracy score, and f1 score, since this problem is rooted in a classification problem and false positives and negatives are essential. We will also employ L1, L2, and MSE loss functions to help guide our model to an optimized implementation.
# </p>

# %% [markdown]
# ----------
# # Data Summary & Descriptions

# %% [markdown]
# ## application_{train|test}.csv
# This file gives us information about the customers. This is the main table, </br> broken into two files for Train (with TARGET) and Test (without TARGET). One row represents one loan in the data sample.

# %% [markdown]
# **Table 1: application_train.csv**
# </br>
# <img src="images/table1.png" width = 800px />

# %% [markdown]
# ![table2.png](attachment:8048c5dd-d021-4162-a778-1c3068c0f8a5.png)**Table 2: application_test.csv**
# </br>
# <img src="images/table2.png" width = 800px />

# %% [markdown]
# ## Bureau.csv
# This dataset contains information about the client's previous credits provided by </br>other financial institutions that were reported to the Credit Bureau. </br>It gives information about the credit limit, what day it is overdue, if it is still active or not.

# %% [markdown]
# **Table 3: bureau.csv**
# </br>
# <img src="images/table3.png" width = 800px />

# %% [markdown]
# ## Bureau_balance.csv
# This dataset gives information about Monthly balances of previous credits in Credit Bureau, </br> the Status of the Credit Bureau loan during the month and  the ID of the Credit Bureau credit. </br> A previous credit can include numerous rows, one for each month of the credit period. </br>Each row represents one month of the previous credit.

# %% [markdown]
# **Table 4: bureau_balance.csv**
# </br>
# <img src="images/table4.png" width = 600px />

# %% [markdown]
# ## POS_CASH_balance.csv
# This dataset gives information about the previous credit information, including the state of the contract,</br> the remaining installments owing, DPD (days past due), etc. of the present application.

# %% [markdown]
# **Table 5: POS_CASH_balance.csv**
# </br>
# <img src="images/table5.png" width = 800px />

# %% [markdown]
# ## Credit_card_balance.csv
# This dataset gives information about the number of transactions of previous credit, installments,the </br> amount of credit limit etc. Every row represents a month's worth of credit card debt, and a single credit </br>card may have several rows.

# %% [markdown]
# **Table 6: Credit_card_balance.csv**
# </br>
# <img src="images/table6.png" width = 800px />

# %% [markdown]
# ## Previous_application.csv
# This dataset gives information about all previous Home Credit loan applications made by customers who have loans in the sample. </br> In this data sample, there is a row for each previous loan application.

# %% [markdown]
# **Table 7: Previous_application.csv**
# </br>
# <img src="images/table7.png" width = 800px />

# %% [markdown]
# ## Installments_payments.csv
# This dataset gives information about repayment history for the Home Credit credits that were previously disbursed in connection with</br> the loans in the sample. There is one row for every payment that was made and one row each for missed payment.  Here one row is equivalent</br> to one payment of one installment.

# %% [markdown]
# **Table 8:  Installments_payments.csv**
# </br>
# <img src="images/table8.png" width = 600px />

# %% [markdown]
# ## HomeCredit_columns_description.csv
# This dataset gives information about descriptions for the columns in the various data files.

# %% [markdown]
# **Table 9: HomeCredit_columns_description.csv**
# </br>
# <img src="images/table9.png" width = 600px />

# %% [markdown]
# ## Data Diagram
# <img src="images/data_diagram.png" width = 600px />

# %% [markdown]
# # Machine Learing Algorithms

# %% [markdown]
# ## Machine Learning - Algorithm Selection
# Given the Home Credit Group’s goal of being able to validate the lendability of an individual with secondary credit data, </br>we must employ appropriate functions that accuratly predict classifying an individual as a lendable or un-lendable individual. </br>That being said, using machine learning algorithms such as linear regression, random forest, and trained neural networks using the </br> optimization function of adagrad seem logical in our goal of classification and minimizing AUC differential from the target.

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# Logistic Regression seems to be a logical option for this data set. Since logistic regression has great flexibility in data sets with relatively lower number of features,</br> we will be able to explore the data and test data analysis methods with this function and get a better picture of the problem itself. </br>Additionally, this method will force us to refine our methods of handling categorical and numerical data since it has no immunity </br>to these characteristic of the data.

# %% [markdown]
# ### Random Forest
# Random Forest seems to be beneficial in this scenario, because there is both categorical and numerical data. From our findings in class we understand that Random Forest handles this data well and can find the intersection between numerical and categorical data easily. Also we believe that this function will allow us to explore the data in meaningful ways. Allowing us to take these lessons into other, more preformant models like a neural network.

# %% [markdown]
# ### Neural Network (Adagrad)

# %% [markdown]
# After previous data analysis and hyper parameter tuning it seems that the most accurate results for this data set will yield from a neural network. We specifically believe that the adagrad optimization will be useful because of its ability to to predict validation functions like area under the curve which is the main scoring mechanism deployed. We believe that adagrad will be a good solution since it is based on gradient descent and we are aiming for a specific value from this descent.

# %% [markdown]
# # Machine Learning - Metrics

# %% [markdown]
# ## Area Under The Curve (AUC)

# %% [markdown]
# $\text{AUC} = \int_{-\infty}^{\infty} \text{TPR}(f) , \text{d}\text{FPR}(f)$

# %% [markdown]
# ## F1 Score

# %% [markdown]
# $F_1 = 2 \cdot \frac{precision \cdot recall}{precision + recall}$

# %% [markdown]
# ## Accuracy Score

# %% [markdown]
# $accuracy = \frac{TP + TN}{TP + TN + FP + FN}$

# %% [markdown]
# Accuracy – It is defined as the percentage of correct prediction of the test data set.
# accuracy =      true positives + true negatives
#                     total number of samples

# %% [markdown]
# ## Machine Learning Pipeline
# <img src="images/mlpipeline.jpg" width = 250px />

# %% [markdown]
# ## Machine Learning Block Diagram
# <img src="images/mlblock.jpg" width = 600px />

# %% [markdown]
# # Gantt Chat: Task Break Down
# <img src="images/gantt_chart.jpg" width = 600px />
